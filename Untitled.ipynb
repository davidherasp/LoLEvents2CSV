# %%
import requests
import json
import pandas as pd
import datetime

# %%
# Getting the match timeline as a JSON
r = requests.get(url="https://acs.leagueoflegends.com/v1/stats/game/TRLH3/1001970008/timeline?gameHash=7aa4a96045584cfe")
response = json.loads(r.content)

# %%
# Creating vars with the info we need (wards)

## Getting the frames
frames = response["frames"]

## Mapping all events into a list
events = list(map(lambda y: y["events"], frames)) 

## Mapping the participant frames into a list
participants = list(map(lambda y: y["participantFrames"], frames)) 

## Grouping al vision related events into a single list
vision_events = list(map(lambda x: list(filter(lambda y: (y["type"] == "WARD_PLACED" or y["type"] == "WARD_KILL"), x)), events))

# %%
# Merging both vision events with the info of the participant of the event

## Creating a list that we will poblate later with all the data
result = []

##Iterating through events frames with the index information
for index, events in enumerate(vision_events):
    ### For every event in that event frame do:
    for event in events:
        #### Check whether if is a placement or a kill to get the participant ID to get the participant info
        if event["type"] == "WARD_PLACED": pid = event["creatorId"]
        else: pid = event["killerId"]
        #### Getting the participant info
        participant = participants[index].get(str(pid))
        #### Merging that info
        merged = dict(list(event.items()) + list(participant.items()))
        #### Adding the frame number
        merged["nFrame"] = index
        #### Appending the data as a new item to the list previously created
        result.append(merged)

## Transforming the list into a Pandas DataFrame 
resultdf = pd.DataFrame.from_dict(result)

# %%
resultdf['x_pos'] = resultdf['position'].apply(lambda d: d['x'])
resultdf['y_pos'] = resultdf['position'].apply(lambda d: d['y'])

resultdf['timestamp'] = resultdf['timestamp'].apply(lambda d: '{:02d}:{:02d}'.format(int(divmod(d/1000, 60)[0]), int(divmod(d/1000, 60)[1])))
resultdf
# Out:
#      creatorId  currentGold  dominionScore  jungleMinionsKilled  killerId  \
# 0          7.0            0              0                    0       NaN
# 1          6.0            0              0                    0       NaN
# 2          4.0           32              0                    0       NaN
# 3         10.0           30              0                    0       NaN
# 4          2.0          114              0                    6       NaN
# 5          9.0          274              0                    0       NaN
# 6          4.0          395              0                    0       NaN
# 7          NaN          163              0                    0      10.0
# 8          5.0          233              0                    0       NaN
# 9          NaN          163              0                    0      10.0
# 10         6.0          308              0                    0       NaN
# 11         2.0          405              0                    8       NaN
# 12         7.0          435              0                    8       NaN
# 13         3.0          413              0                    0       NaN
# 14         NaN          824              0                   13       7.0
# 15         3.0          736              0                    0       NaN
# 16         5.0          406              0                    0       NaN
# 17         1.0           31              0                    0       NaN
# 18         9.0          685              0                    0       NaN
# 19         8.0          278              0                    0       NaN
# 20         8.0          278              0                    0       NaN
# 21        10.0          573              0                    0       NaN
# 22         7.0           30              0                   23       NaN
# 23         2.0           20              0                   23       NaN
# 24         4.0         1510              0                    0       NaN
# 25         7.0          303              0                   29       NaN
# 26         5.0          775              0                    0       NaN
# 27         3.0         1397              0                    0       NaN
# 28         NaN         1397              0                    0       3.0
# 29         3.0         1397              0                    0       NaN
# ..         ...          ...            ...                  ...       ...
# 351        7.0          445              0                  163       NaN
# 352        5.0          476              0                    0       NaN
# 353        1.0          800              0                   16       NaN
# 354        NaN          800              0                   16       1.0
# 355        5.0          476              0                    0       NaN
# 356        4.0          429              0                    8       NaN
# 357        NaN          326              0                  174       2.0
# 358        4.0          429              0                    8       NaN
# 359        5.0          716              0                    0       NaN
# 360        6.0          392              0                    3       NaN
# 361        6.0          392              0                    3       NaN
# 362        3.0          299              0                   17       NaN
# 363        NaN          964              0                    8       4.0
# 364        4.0          964              0                    8       NaN
# 365        4.0          964              0                    8       NaN
# 366        9.0          842              0                    4       NaN
# 367        4.0          964              0                    8       NaN
# 368        NaN          995              0                  175       2.0
# 369        NaN         1200              0                    0       5.0
# 370        NaN          683              0                    0      10.0
# 371        5.0         1200              0                    0       NaN
# 372        NaN         1021              0                  166       7.0
# 373        4.0          964              0                    8       NaN
# 374        NaN          683              0                    0      10.0
# 375        4.0          964              0                    8       NaN
# 376        7.0         1698              0                  166       NaN
# 377       10.0         1034              0                    0       NaN
# 378        NaN         2914              0                   26       1.0
# 379        1.0         2914              0                   26       NaN
# 380        NaN         1698              0                  166       7.0
#
#      level  minionsKilled  nFrame  participantId                  position  \
# 0        1              0       1              7    {'x': 7263, 'y': 9831}
# 1        1              0       1              6   {'x': 4510, 'y': 11722}
# 2        1              1       2              4   {'x': 12240, 'y': 1695}
# 3        1              1       2             10   {'x': 12549, 'y': 2695}
# 4        2              0       2              2    {'x': 7267, 'y': 3888}
# 5        2              8       3              9   {'x': 12446, 'y': 2910}
# 6        2             14       3              4   {'x': 11558, 'y': 1778}
# 7        2              1       3             10   {'x': 11946, 'y': 2818}
# 8        2              3       3              5   {'x': 12847, 'y': 2100}
# 9        2              1       3             10   {'x': 11946, 'y': 2818}
# 10       2             10       3              6   {'x': 3157, 'y': 13611}
# 11       2              0       3              2    {'x': 8465, 'y': 2156}
# 12       3              0       3              7   {'x': 12417, 'y': 6649}
# 13       3             14       3              3    {'x': 6898, 'y': 6494}
# 14       4              1       4              7    {'x': 3426, 'y': 8917}
# 15       4             25       4              3    {'x': 6581, 'y': 8402}
# 16       3              4       4              5   {'x': 12799, 'y': 2223}
# 17       3             18       4              1      {'x': 394, 'y': 461}
# 18       3             22       4              9   {'x': 13051, 'y': 3296}
# 19       5             37       5              8    {'x': 8125, 'y': 6433}
# 20       5             37       5              8    {'x': 8125, 'y': 6433}
# 21       4              7       5             10   {'x': 13218, 'y': 2603}
# 22       4              1       5              7  {'x': 12410, 'y': 12313}
# 23       4              0       5              2    {'x': 2099, 'y': 1085}
# 24       4             50       6              4   {'x': 12901, 'y': 2467}
# 25       5              3       6              7    {'x': 8382, 'y': 6237}
# 26       4              7       6              5   {'x': 13524, 'y': 2731}
# 27       6             46       6              3    {'x': 5444, 'y': 6136}
# 28       6             46       6              3    {'x': 5444, 'y': 6136}
# 29       6             46       6              3    {'x': 5444, 'y': 6136}
# ..     ...            ...     ...            ...                       ...
# 351     16             35      36              7   {'x': 6967, 'y': 13202}
# 352     14             69      36              5    {'x': 7083, 'y': 6703}
# 353     18            323      36              1   {'x': 13248, 'y': 3645}
# 354     18            323      36              1   {'x': 13248, 'y': 3645}
# 355     14             69      36              5    {'x': 7083, 'y': 6703}
# 356     16            329      37              4    {'x': 9571, 'y': 9227}
# 357     17             62      37              2    {'x': 5082, 'y': 9178}
# 358     16            329      37              4    {'x': 9571, 'y': 9227}
# 359     14             70      37              5    {'x': 9948, 'y': 9363}
# 360     17            336      37              6  {'x': 14340, 'y': 14391}
# 361     17            336      37              6  {'x': 14340, 'y': 14391}
# 362     18            360      37              3    {'x': 9824, 'y': 9362}
# 363     17            333      38              4  {'x': 13588, 'y': 10268}
# 364     17            333      38              4  {'x': 13588, 'y': 10268}
# 365     17            333      38              4  {'x': 13588, 'y': 10268}
# 366     17            352      38              9  {'x': 12795, 'y': 12228}
# 367     17            333      38              4  {'x': 13588, 'y': 10268}
# 368     18             71      38              2  {'x': 11646, 'y': 11235}
# 369     15             70      38              5   {'x': 12999, 'y': 9768}
# 370     14             30      38             10   {'x': 13303, 'y': 9948}
# 371     15             70      38              5   {'x': 12999, 'y': 9768}
# 372     16             45      38              7  {'x': 10068, 'y': 13615}
# 373     17            333      38              4  {'x': 13588, 'y': 10268}
# 374     14             30      38             10   {'x': 13303, 'y': 9948}
# 375     17            333      38              4  {'x': 13588, 'y': 10268}
# 376     16             53      39              7   {'x': 5798, 'y': 10437}
# 377     14             33      39             10   {'x': 7122, 'y': 11532}
# 378     18            358      39              1   {'x': 6592, 'y': 11332}
# 379     18            358      39              1   {'x': 6592, 'y': 11332}
# 380     16             53      39              7   {'x': 5798, 'y': 10437}
#
#      teamScore timestamp  totalGold         type        wardType     xp  \
# 0            0     01:05        500  WARD_PLACED  YELLOW_TRINKET      0
# 1            0     01:12        500  WARD_PLACED  YELLOW_TRINKET      0
# 2            0     02:05        532  WARD_PLACED  YELLOW_TRINKET     38
# 3            0     02:19        530  WARD_PLACED  YELLOW_TRINKET    134
# 4            0     02:43        614  WARD_PLACED  YELLOW_TRINKET    346
# 5            0     03:08        774  WARD_PLACED  YELLOW_TRINKET    326
# 6            0     03:16        895  WARD_PLACED  YELLOW_TRINKET    422
# 7            0     03:19        663    WARD_KILL  YELLOW_TRINKET    326
# 8            0     03:23        733  WARD_PLACED  YELLOW_TRINKET    422
# 9            0     03:26        663    WARD_KILL  YELLOW_TRINKET    326
# 10           0     03:44        808  WARD_PLACED  YELLOW_TRINKET    588
# 11           0     03:54        905  WARD_PLACED  YELLOW_TRINKET    655
# 12           0     03:56        935  WARD_PLACED  YELLOW_TRINKET    726
# 13           0     03:57        913  WARD_PLACED  YELLOW_TRINKET    798
# 14           0     04:00       1324    WARD_KILL  YELLOW_TRINKET   1201
# 15           0     04:00       1236  WARD_PLACED  YELLOW_TRINKET   1416
# 16           0     04:18        906  WARD_PLACED  YELLOW_TRINKET    751
# 17           0     04:21       1111  WARD_PLACED  YELLOW_TRINKET   1092
# 18           0     04:30       1185  WARD_PLACED  YELLOW_TRINKET    914
# 19           0     05:02       1603  WARD_PLACED       UNDEFINED   1862
# 20           0     05:05       1603  WARD_PLACED  YELLOW_TRINKET   1862
# 21           0     05:16       1073  WARD_PLACED  YELLOW_TRINKET   1224
# 22           0     05:29       1605  WARD_PLACED       UNDEFINED   1430
# 23           0     05:34       1595  WARD_PLACED      SIGHT_WARD   1612
# 24           0     06:05       2010  WARD_PLACED  YELLOW_TRINKET   1580
# 25           0     06:11       1878  WARD_PLACED  YELLOW_TRINKET   1810
# 26           0     06:26       1275  WARD_PLACED  YELLOW_TRINKET   1521
# 27           0     06:49       1897  WARD_PLACED  YELLOW_TRINKET   2498
# 28           0     06:56       1897    WARD_KILL       UNDEFINED   2498
# 29           0     06:57       1897  WARD_PLACED       UNDEFINED   2498
# ..         ...       ...        ...          ...             ...    ...
# 351          0     36:45      11610  WARD_PLACED       UNDEFINED  14727
# 352          0     36:51       9552  WARD_PLACED      SIGHT_WARD  12163
# 353          0     36:53      15164  WARD_PLACED    BLUE_TRINKET  19598
# 354          0     36:56      15164    WARD_KILL    BLUE_TRINKET  19598
# 355          0     36:57       9552  WARD_PLACED       UNDEFINED  12163
# 356          0     37:04      14184  WARD_PLACED       UNDEFINED  16210
# 357          0     37:11      14506    WARD_KILL       UNDEFINED  18159
# 358          0     37:14      14184  WARD_PLACED       UNDEFINED  16210
# 359          0     37:22       9791  WARD_PLACED      SIGHT_WARD  12385
# 360          0     37:47      13042  WARD_PLACED    BLUE_TRINKET  17490
# 361          0     37:52      13042  WARD_PLACED       UNDEFINED  17490
# 362          0     37:56      16518  WARD_PLACED    BLUE_TRINKET  20825
# 363          0     38:06      14718    WARD_KILL       UNDEFINED  16723
# 364          0     38:13      14718  WARD_PLACED       UNDEFINED  16723
# 365          0     38:21      14718  WARD_PLACED       UNDEFINED  16723
# 366          0     38:26      13211  WARD_PLACED    BLUE_TRINKET  16494
# 367          0     38:27      14718  WARD_PLACED       UNDEFINED  16723
# 368          0     38:27      15174    WARD_KILL    BLUE_TRINKET  19035
# 369          0     38:31      10275    WARD_KILL       UNDEFINED  13276
# 370          0     38:41       8318    WARD_KILL       UNDEFINED  11768
# 371          0     38:41      10275  WARD_PLACED       UNDEFINED  13276
# 372          0     38:43      12186    WARD_KILL       UNDEFINED  15417
# 373          0     38:49      14718  WARD_PLACED    BLUE_TRINKET  16723
# 374          0     38:51       8318    WARD_KILL    BLUE_TRINKET  11768
# 375          0     38:54      14718  WARD_PLACED       UNDEFINED  16723
# 376          0     39:06      12864  WARD_PLACED       UNDEFINED  16288
# 377          0     39:08       8669  WARD_PLACED      SIGHT_WARD  12047
# 378          0     39:13      17778    WARD_KILL    BLUE_TRINKET  22994
# 379          0     39:42      17778  WARD_PLACED    BLUE_TRINKET  22994
# 380          0     39:44      12864    WARD_KILL    BLUE_TRINKET  16288
#
#      x_pos  y_pos
# 0     7263   9831
# 1     4510  11722
# 2    12240   1695
# 3    12549   2695
# 4     7267   3888
# 5    12446   2910
# 6    11558   1778
# 7    11946   2818
# 8    12847   2100
# 9    11946   2818
# 10    3157  13611
# 11    8465   2156
# 12   12417   6649
# 13    6898   6494
# 14    3426   8917
# 15    6581   8402
# 16   12799   2223
# 17     394    461
# 18   13051   3296
# 19    8125   6433
# 20    8125   6433
# 21   13218   2603
# 22   12410  12313
# 23    2099   1085
# 24   12901   2467
# 25    8382   6237
# 26   13524   2731
# 27    5444   6136
# 28    5444   6136
# 29    5444   6136
# ..     ...    ...
# 351   6967  13202
# 352   7083   6703
# 353  13248   3645
# 354  13248   3645
# 355   7083   6703
# 356   9571   9227
# 357   5082   9178
# 358   9571   9227
# 359   9948   9363
# 360  14340  14391
# 361  14340  14391
# 362   9824   9362
# 363  13588  10268
# 364  13588  10268
# 365  13588  10268
# 366  12795  12228
# 367  13588  10268
# 368  11646  11235
# 369  12999   9768
# 370  13303   9948
# 371  12999   9768
# 372  10068  13615
# 373  13588  10268
# 374  13303   9948
# 375  13588  10268
# 376   5798  10437
# 377   7122  11532
# 378   6592  11332
# 379   6592  11332
# 380   5798  10437
#
# [381 rows x 18 columns]

# %%
# Some corrections over the data

## Removing the participantID column since the data is redundant because we already have the ID in the creatorId or in the killerId
del resultdf["participantId"]
## Removing as well the position since we previously added two new columns with that data
del resultdf["position"]

# %%
# In order to convert the ids into integers we need to replace NA values with something acceptable that clearly indicates that the value represents something completly different as expectet, like -1
resultdf = resultdf.fillna(-1)
# Out:
#     creatorId  currentGold  dominionScore  jungleMinionsKilled killerId  \
# 0           7            0              0                    0       NA
# 1           6            0              0                    0       NA
# 2           4           32              0                    0       NA
# 3          10           30              0                    0       NA
# 4           2          114              0                    6       NA
# 5           9          274              0                    0       NA
# 6           4          395              0                    0       NA
# 7          NA          163              0                    0       10
# 8           5          233              0                    0       NA
# 9          NA          163              0                    0       10
# 10          6          308              0                    0       NA
# 11          2          405              0                    8       NA
# 12          7          435              0                    8       NA
# 13          3          413              0                    0       NA
# 14         NA          824              0                   13        7
# 15          3          736              0                    0       NA
# 16          5          406              0                    0       NA
# 17          1           31              0                    0       NA
# 18          9          685              0                    0       NA
# 19          8          278              0                    0       NA
# 20          8          278              0                    0       NA
# 21         10          573              0                    0       NA
# 22          7           30              0                   23       NA
# 23          2           20              0                   23       NA
# 24          4         1510              0                    0       NA
# 25          7          303              0                   29       NA
# 26          5          775              0                    0       NA
# 27          3         1397              0                    0       NA
# 28         NA         1397              0                    0        3
# 29          3         1397              0                    0       NA
# ..        ...          ...            ...                  ...      ...
# 351         7          445              0                  163       NA
# 352         5          476              0                    0       NA
# 353         1          800              0                   16       NA
# 354        NA          800              0                   16        1
# 355         5          476              0                    0       NA
# 356         4          429              0                    8       NA
# 357        NA          326              0                  174        2
# 358         4          429              0                    8       NA
# 359         5          716              0                    0       NA
# 360         6          392              0                    3       NA
# 361         6          392              0                    3       NA
# 362         3          299              0                   17       NA
# 363        NA          964              0                    8        4
# 364         4          964              0                    8       NA
# 365         4          964              0                    8       NA
# 366         9          842              0                    4       NA
# 367         4          964              0                    8       NA
# 368        NA          995              0                  175        2
# 369        NA         1200              0                    0        5
# 370        NA          683              0                    0       10
# 371         5         1200              0                    0       NA
# 372        NA         1021              0                  166        7
# 373         4          964              0                    8       NA
# 374        NA          683              0                    0       10
# 375         4          964              0                    8       NA
# 376         7         1698              0                  166       NA
# 377        10         1034              0                    0       NA
# 378        NA         2914              0                   26        1
# 379         1         2914              0                   26       NA
# 380        NA         1698              0                  166        7
#
#      level  minionsKilled  nFrame  teamScore  timestamp  totalGold  \
# 0        1              0       1          0      65502        500
# 1        1              0       1          0      72603        500
# 2        1              1       2          0     125952        532
# 3        1              1       2          0     139444        530
# 4        2              0       2          0     163238        614
# 5        2              8       3          0     188097        774
# 6        2             14       3          0     196908        895
# 7        2              1       3          0     199501        663
# 8        2              3       3          0     203391        733
# 9        2              1       3          0     206182        663
# 10       2             10       3          0     224107        808
# 11       2              0       3          0     234718        905
# 12       3              0       3          0     236571        935
# 13       3             14       3          0     237835        913
# 14       4              1       4          0     240190       1324
# 15       4             25       4          0     240320       1236
# 16       3              4       4          0     258526        906
# 17       3             18       4          0     261906       1111
# 18       3             22       4          0     270989       1185
# 19       5             37       5          0     302356       1603
# 20       5             37       5          0     305114       1603
# 21       4              7       5          0     316167       1073
# 22       4              1       5          0     329736       1605
# 23       4              0       5          0     334959       1595
# 24       4             50       6          0     365371       2010
# 25       5              3       6          0     371687       1878
# 26       4              7       6          0     386708       1275
# 27       6             46       6          0     409940       1897
# 28       6             46       6          0     416509       1897
# 29       6             46       6          0     417677       1897
# ..     ...            ...     ...        ...        ...        ...
# 351     16             35      36          0    2205895      11610
# 352     14             69      36          0    2211460       9552
# 353     18            323      36          0    2213646      15164
# 354     18            323      36          0    2216301      15164
# 355     14             69      36          0    2217907       9552
# 356     16            329      37          0    2224379      14184
# 357     17             62      37          0    2231603      14506
# 358     16            329      37          0    2234508      14184
# 359     14             70      37          0    2242055       9791
# 360     17            336      37          0    2267396      13042
# 361     17            336      37          0    2272665      13042
# 362     18            360      37          0    2276547      16518
# 363     17            333      38          0    2286745      14718
# 364     17            333      38          0    2293990      14718
# 365     17            333      38          0    2301222      14718
# 366     17            352      38          0    2306448      13211
# 367     17            333      38          0    2307301      14718
# 368     18             71      38          0    2307797      15174
# 369     15             70      38          0    2311134      10275
# 370     14             30      38          0    2321458       8318
# 371     15             70      38          0    2321556      10275
# 372     16             45      38          0    2323876      12186
# 373     17            333      38          0    2329425      14718
# 374     14             30      38          0    2331063       8318
# 375     17            333      38          0    2334725      14718
# 376     16             53      39          0    2346240      12864
# 377     14             33      39          0    2348556       8669
# 378     18            358      39          0    2353165      17778
# 379     18            358      39          0    2382500      17778
# 380     16             53      39          0    2384522      12864
#
#             type        wardType     xp  x_pos  y_pos
# 0    WARD_PLACED  YELLOW_TRINKET      0   7263   9831
# 1    WARD_PLACED  YELLOW_TRINKET      0   4510  11722
# 2    WARD_PLACED  YELLOW_TRINKET     38  12240   1695
# 3    WARD_PLACED  YELLOW_TRINKET    134  12549   2695
# 4    WARD_PLACED  YELLOW_TRINKET    346   7267   3888
# 5    WARD_PLACED  YELLOW_TRINKET    326  12446   2910
# 6    WARD_PLACED  YELLOW_TRINKET    422  11558   1778
# 7      WARD_KILL  YELLOW_TRINKET    326  11946   2818
# 8    WARD_PLACED  YELLOW_TRINKET    422  12847   2100
# 9      WARD_KILL  YELLOW_TRINKET    326  11946   2818
# 10   WARD_PLACED  YELLOW_TRINKET    588   3157  13611
# 11   WARD_PLACED  YELLOW_TRINKET    655   8465   2156
# 12   WARD_PLACED  YELLOW_TRINKET    726  12417   6649
# 13   WARD_PLACED  YELLOW_TRINKET    798   6898   6494
# 14     WARD_KILL  YELLOW_TRINKET   1201   3426   8917
# 15   WARD_PLACED  YELLOW_TRINKET   1416   6581   8402
# 16   WARD_PLACED  YELLOW_TRINKET    751  12799   2223
# 17   WARD_PLACED  YELLOW_TRINKET   1092    394    461
# 18   WARD_PLACED  YELLOW_TRINKET    914  13051   3296
# 19   WARD_PLACED       UNDEFINED   1862   8125   6433
# 20   WARD_PLACED  YELLOW_TRINKET   1862   8125   6433
# 21   WARD_PLACED  YELLOW_TRINKET   1224  13218   2603
# 22   WARD_PLACED       UNDEFINED   1430  12410  12313
# 23   WARD_PLACED      SIGHT_WARD   1612   2099   1085
# 24   WARD_PLACED  YELLOW_TRINKET   1580  12901   2467
# 25   WARD_PLACED  YELLOW_TRINKET   1810   8382   6237
# 26   WARD_PLACED  YELLOW_TRINKET   1521  13524   2731
# 27   WARD_PLACED  YELLOW_TRINKET   2498   5444   6136
# 28     WARD_KILL       UNDEFINED   2498   5444   6136
# 29   WARD_PLACED       UNDEFINED   2498   5444   6136
# ..           ...             ...    ...    ...    ...
# 351  WARD_PLACED       UNDEFINED  14727   6967  13202
# 352  WARD_PLACED      SIGHT_WARD  12163   7083   6703
# 353  WARD_PLACED    BLUE_TRINKET  19598  13248   3645
# 354    WARD_KILL    BLUE_TRINKET  19598  13248   3645
# 355  WARD_PLACED       UNDEFINED  12163   7083   6703
# 356  WARD_PLACED       UNDEFINED  16210   9571   9227
# 357    WARD_KILL       UNDEFINED  18159   5082   9178
# 358  WARD_PLACED       UNDEFINED  16210   9571   9227
# 359  WARD_PLACED      SIGHT_WARD  12385   9948   9363
# 360  WARD_PLACED    BLUE_TRINKET  17490  14340  14391
# 361  WARD_PLACED       UNDEFINED  17490  14340  14391
# 362  WARD_PLACED    BLUE_TRINKET  20825   9824   9362
# 363    WARD_KILL       UNDEFINED  16723  13588  10268
# 364  WARD_PLACED       UNDEFINED  16723  13588  10268
# 365  WARD_PLACED       UNDEFINED  16723  13588  10268
# 366  WARD_PLACED    BLUE_TRINKET  16494  12795  12228
# 367  WARD_PLACED       UNDEFINED  16723  13588  10268
# 368    WARD_KILL    BLUE_TRINKET  19035  11646  11235
# 369    WARD_KILL       UNDEFINED  13276  12999   9768
# 370    WARD_KILL       UNDEFINED  11768  13303   9948
# 371  WARD_PLACED       UNDEFINED  13276  12999   9768
# 372    WARD_KILL       UNDEFINED  15417  10068  13615
# 373  WARD_PLACED    BLUE_TRINKET  16723  13588  10268
# 374    WARD_KILL    BLUE_TRINKET  11768  13303   9948
# 375  WARD_PLACED       UNDEFINED  16723  13588  10268
# 376  WARD_PLACED       UNDEFINED  16288   5798  10437
# 377  WARD_PLACED      SIGHT_WARD  12047   7122  11532
# 378    WARD_KILL    BLUE_TRINKET  22994   6592  11332
# 379  WARD_PLACED    BLUE_TRINKET  22994   6592  11332
# 380    WARD_KILL    BLUE_TRINKET  16288   5798  10437
#
# [381 rows x 16 columns]

# %%
# Then we convert the float values of the id columns into integer values
resultdf["creatorId"] = resultdf["creatorId"].astype(int)
resultdf["killerId"] = resultdf["killerId"].astype(int)
# Then we replace the -1 for NA 
resultdf = resultdf.replace(to_replace=-1, value="NA")
# And finally we export the dataframe into a CSV
resultdf.to_csv("vision_events.csv")
